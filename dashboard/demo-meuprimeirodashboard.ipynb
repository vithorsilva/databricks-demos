# %% [markdown]
# # Sobre mim
# **Vithor Silva** é CTO na Datasource Expert, com vasta experiência como consultor e instrutor especializado em produtos Microsoft, Databricks, Azure, SQL Server e PowerBI.
#
# <img src="https://avatars.githubusercontent.com/u/24571476" width="200" alt="Alt text" />
#
# Participe do nosso grupo de usuários de Databricks, acesse [clicando aqui.](https://usergroups.databricks.com/espirito-santo-databricks-user-group/)
#
# Quer bater um papo sobre Databricks? Marque um horário [comigo](https://outlook.office.com/bookwithme/user/05ee80e4360e4615966e7b614de37234%40datasource.expert/meetingtype/bWZ3sSul5kyywIcspS9K2g2?anonymous&ismsaljsauthenabled=true).

# %% [markdown]
# # Setup

# %% [markdown]
# Execute as células a seguir para fazer a instalação da base necessária para a sequência da demonstração

# %%
# %pip install dbdemos

# %% [markdown]
# Criação dos dados necessários e instalação de dashboard pronto para uso.

# %%
import dbdemos
dbdemos.install('aibi-sales-pipeline-review', catalog='main', schema='dbdemos_aibi_sales_pipeline_review')

# %% [markdown]
# # Introdução

# %% [markdown]
# Seguindo este roteiro, você será guiado ao longo da apresentação para construir o dashboard dash-vendas-pipeline-pronto:
#
# 1. Crie um novo dashboard e nomeie como "dash-vendas-pipeline-pronto".
# 2. Adicione uma aba chamada "Indicadores".
# 3. Clique em "Data" e insira a query SQL com as colunas e joins necessários para oportunidades, contas e vendedores.
# 4. Salve o dataset como "dataset_oportunidades".
# 5. Execute e pré-visualize os dados.
# 6. Adicione visualizações na aba "Indicadores":
#    * Cartão: Quantidade de oportunidades no pipeline
#    * Gráfico de Linha: Oportunidades ao longo do tempo (ex: fechamento por mês, agrupado por região)
#    * Personalize os gráficos conforme necessário.
# 7. Configure Filtros Globais (exemplo: período de fechamento da oportunidade).
# 8. Experimente adicionar diferentes tipos de gráficos e filtros interativos.
# 9. Crie uma aba "Detalhamento" para tabelas e drill-through.
# 10. Teste a navegação entre as abas usando o drill-through.
# 11. Ajuste o layout e configure o tema global do dashboard.
#
# Com esse roteiro, você será capaz de acompanhar cada etapa, construir dashboards interativos e visualmente atrativos, e apoiar a tomada de decisão no Databricks durante a apresentação.

# %% [markdown]
# # Roteiro

# %% [markdown]
# ## Criando um Dashboard
#
# Conecte-se ao seu ambiente Databricks (inclusive o Free Edition), clique em Dashboards e depois em "Create Dashboard".
# ![dashboard1-tutorial-1](./images/dashboard1-tutorial-1.png "Tutorial - Meu Primeiro Dashboard")
#
# Uma nova tela será aberta, destacando pontos importantes:
# ![dashboard1-tutorial-1](./images/dashboard1-tutorial-2.png "Tutorial - Meu Primeiro Dashboard")
#
# * **Data**: Adicione os dados que serão usados nos itens visuais (gráficos). Os Dashboards do Databricks utilizam datasets, permitindo que cada gráfico esteja vinculado a um dataset específico. Para relacioná-los, utilize filtros ou parâmetros.
# * **Páginas**: É possível criar dashboards com várias abas/páginas, permitindo interação entre os dados. Distribua as informações para facilitar a navegação.
# * **Filtros Globais**: Filtros impactam todos os gráficos/datasets vinculados, tornando a análise dinâmica.
# * **Visualizações**: Adicione diferentes tipos de gráficos (barras, linhas, pizza, tabelas, mapas, etc.), personalize cores, títulos, eixos e legendas.
# * **Parâmetros**: Crie parâmetros dinâmicos para personalizar consultas SQL ou visualizações, tornando o dashboard interativo.
# * **Layout**: Organize os elementos do dashboard arrastando e redimensionando itens, criando uma experiência visual adequada.
# * **Compartilhamento**: Compartilhe dashboards com outros usuários, defina como público ou privado e agende atualizações automáticas.
# * **Exportação**: Exporte dashboards em PDF ou imagens para apresentações externas.
# * **Comentários**: Adicione comentários e anotações diretamente nos dashboards para facilitar a colaboração.
# * **Agendamento**: Configure atualizações automáticas dos dados para manter as visualizações sempre atualizadas.
#
# Essas funcionalidades permitem criar dashboards completos, interativos e colaborativos no Databricks, facilitando a análise e visualização dos dados.

# %% [markdown]
# ## Passo a passo
#
# 1. Nomeie o dashboard como "dash-vendas-pipeline"
# 2. Nome a aba para "Indicadores"
# 3. Clique em "Data" para adicionarmos uma instrução SQL, ao qual será:
#
# ```sql
# select
#     -- Dados sobre o Lead (Dimensões)
#     o.opportunityid, o.type, o.name as opportunity, /*o.description,*/ o.createddate, o.closedate, o.days_to_close, o.leadsource,
#     -- Dados sobre a Conta (Dimensões)
#     o.accountid, o.account_name, o.industry as account_industry, o.business_type__c as industry_businesstype,
#     o.region as account_region, o.company_size_segment__c as account_sizesegment, o.region_size as account_region_size, o.annualrevenue as account_annualrevenue,
#     -- Dados sobre o Vendedor (Dimensões)
#     o.ownerid, u.name as salesman, sup.name as salesman_manager ,
#     o.probability,
#     o.stagename,
#     o.forecastcategory,
#     -- Medidas
#     o.amount, o.opportunity_amount,
#     o.New_Expansion_Booking_Annual__c,
#     o.New_Expansion_Booking_Annual_Wtd__c,
#     o.New_Recurring_Bookings_Manual__c,
#     o.New_Recurring_Bookings__c
# from main.dbdemos_aibi_sales_pipeline_review.opportunity o
# inner join main.dbdemos_aibi_sales_pipeline_review.user u on o.ownerid = u.id
# LEFT join main.dbdemos_aibi_sales_pipeline_review.user sup on sup.id = u.managerid
# ```
# 4. Nomeie o dataset para "dataset_oportunidades", conforme imagem a seguir:
# ![dashboard1-tutorial-3](./images/dashboard1-tutorial-3.png "Tutorial - Meu Primeiro Dashboard")
# 5. Clique em "Run" para pré-visualizar os dados;
# 6. Por fim, retorne a aba "Indicadores" para iniciarmos a construção dos gráficos;
# 7. **Cartão (Card)**: Faremos um gráfico sobre a quantidade de oportunidades no pipeline de vendas
# ![Databricks - Card](./images/databricks-primeirodashboard-card.gif "Tutorial - Meu Primeiro Dashboard")
# 8. **Gráfico de Linha**: Faremos um gráfico com a quantidade de oportunidades mês a mês
# ![Databricks - Linha](./images/databricks-primeirodashboard-line.gif "Tutorial - Meu Primeiro Dashboard")
# Observando a paleta de configurações do gráfico, facilmente podemos ajustá-lo para complementar a análise, deixando-o mais completo, na imagem abaixo adicionei o campo account_region, mostrando assim cada linha a quantidade de oportunidades por região.
# ![dashboard1-tutorial-4](./images/dashboard1-tutorial-4.png "Tutorial - Meu Primeiro Dashboard")
# 9. **Personalizações**: Ao clicar na área com (...) é possível ver algumas opções adicionais, então, sempre observe que pode algum ajuste ser realizado nesta área:
# ![dashboard1-tutorial-5](./images/dashboard1-tutorial-5.png "Tutorial - Meu Primeiro Dashboard")
# 10. Experimente adicionar outros componentes gráficos, incluindo os filtros.
# 11. **Filtros Globais**: Definiremos como filtro o período de fechamento da oportunidade, podemos fazer isto de forma simples:
# ![Filtros Globais](./images/databricks-primeirodashboard-filtrosglobais.gif "Tutorial - Meu Primeiro Dashboard")
# Experimente a funcionalidade adicionando outros filtros.
# 12. Uma visão básica poderia ser a seguinte ao final:
# ![dashboard1-tutorial-5](./images/dashboard1-tutorial-7.png "Tutorial - Meu Primeiro Dashboard")
# 13. Agora criaremos uma nova aba, com nome "Detalhamento" e adicionaremos uma tabela com diversos campos úteis. Em outras ferramentas, é muito comum a necessidade de fazer o *drill-through* e agora nós conheceremos como fazê-lo;
# ![Databricks - Drill-Through](./images/databricks-primeirodashboard-drill.gif "Tutorial - Meu Primeiro Dashboard")
# Na imagem acima, é demonstrado a adição da tabela e remoção de alguns campos, mantenha apenas o que entender ser interessante para o usuário final;
# 14. Voltemos a aba "Indicadores" para testar a integração entre elas, com a funcionalidades de *drill-through*. Vejamos:
# ![Databricks - Drill-Through em ação](./images/databricks-primeirodashboard-drill-emacao.gif "Tutorial - Meu Primeiro Dashboard")
# 20. Configurações globais do dashboard, podem ser ajustados clicando em "settings" em uma área livre do canvas. Assim, pode ser configurado um tema com a paleta de cores adequada da empresa ou utilizando *templates* prontos, experimente!

# %% [markdown]
# # Conclusão

# %% [markdown]
# Os Dashboards do Databricks oferecem uma solução prática e flexível para análise de dados e visualização de indicadores estratégicos.
#
# Ao integrar datasets, automação de atualizações, filtros dinâmicos e diversas opções de visualizações, eles facilitam a colaboração entre equipes e a tomada de decisões baseada em dados.
#
# Com recursos como drill-through, personalização de layout e compartilhamento, as organizações podem configurar painéis sob medida que promovem transparência, agilidade e insights mais profundos, acelerando a transformação digital e produtividade nas operações.
